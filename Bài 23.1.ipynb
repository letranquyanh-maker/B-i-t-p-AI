# %%
import folium
m = folium.Map(location = [10.761387172807378, 106.66832446760228], zoom_start =13)


UEH = folium.FeatureGroup(name='UEH')
benhvien = folium.FeatureGroup(name='benhvien')
benxe = folium.FeatureGroup(name='benxe')
vanphong = folium.FeatureGroup(name='vanphong')


folium.Marker([10.761387172807378, 106.66832446760228], popup = 'UEH_B', tooltip = 'click').add_to(UEH)
folium.Marker([10.756437587656471, 106.67500804937534], popup = 'Bệnh viện Nguyễn Trãi', tooltip = 'click').add_to(benhvien)
folium.Marker([10.755784086852133, 106.66468690995083], popup = 'Bệnh viện Đại học Y Dược TP.HCM', tooltip = 'click').add_to(benhvien)
folium.Marker([10.758650962747577, 106.67078088778803], popup = 'Bến xe Hoa Mai', tooltip = 'click').add_to(benxe)
folium.Marker([10.760075181254578, 106.67756549147174], popup = 'Bến Xe Phương Trang', tooltip = 'click').add_to(benxe)
folium.Marker([10.763852330888913, 106.66839229337961], popup = 'Văn phòng Kinh tế và Văn hóa Đài Bắc tại TP.HCM', tooltip = 'click').add_to(vanphong)


UEH.add_to(m)
benhvien.add_to(m)
benxe.add_to(m)
vanphong.add_to(m)


folium.LayerControl().add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
